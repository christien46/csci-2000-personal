# %%
#Christien Soosaipillai
#100557844

#IMPORTS
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from JSAnimation.IPython_display import display_animation
import urllib
from mpl_toolkits.basemap import Basemap
import csv

Category = []
Lat = []
Long = []
Cases = []


#initialize all variables within each array used to hold position
q1 = 0  #Measles
q2 = 0  #Rubella
q3 = 0  #Mumps
q4 = 0  #Polio


#Access the csv file and get all the information neccessary
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))
#reading from columns

#Earthquake program from lecture to make a map of the earth
plt.figure(figsize=(12, 12))
earth = Basemap(projection='mill')
earth.fillcontinents(color='0.85')
earth.drawcoastlines(color='0.60', linewidth=0.55)
        
        
#Change strings into float values
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))


#search all data matching measles
for a in range (q1, len(Category)):
    if (Category[q1] == 'Measles'):
        x, y = earth(Long[q1], Lat[q1])
        
        #if measelse is found increase size the more cases that are there
        if (Cases[q1] >= 0 and Cases[q1] < 5000):
            earth.plot(x, y, 'ro',markersize=5,alpha=.35)
            
        elif (Cases[q1] >= 5000 and Cases[q1] < 10000):
            earth.plot(x, y, 'ro',markersize=10,alpha=.35)
            
        elif (Cases[q1] >= 10000 and Cases[q1] < 15000):
            earth.plot(x, y, 'ro',markersize=15,alpha=.35)
            
        elif (Cases[q1] >= 15000 and Cases[q1] < 20000):
            earth.plot(x, y, 'ro',markersize=20,alpha=.35)
            
        elif (Cases[q1] >= 20000 and Cases[q1] < 25000):
            earth.plot(x, y, 'ro',markersize=25,alpha=.35)
            
        elif (Cases[q1] >= 25000 and Cases[q1] < 30000):
            earth.plot(x, y, 'ro',markersize=30,alpha=.35)
            
        elif (Cases[q1] >= 30000 and Cases[q1] < 35000):
            earth.plot(x, y, 'ro',markersize=35,alpha=.35)
            
        elif (Cases[q1] >= 35000 and Cases[q1] < 40000):
            earth.plot(x, y, 'ro',markersize=40,alpha=.35)
            
        elif (Cases[q1] >= 40000 and Cases[q1] < 45000):
            earth.plot(x, y, 'ro',markersize=45,alpha=.35)
            
        elif (Cases[q1] >= 45000 and Cases[q1] < 50000):
            earth.plot(x, y, 'ro',markersize=50,alpha=.35)
            
        elif (Cases[q1] >= 50000 and Cases[q1] < 55000):
            earth.plot(x, y, 'ro',markersize=55,alpha=.35)
            
        elif (Cases[q1] >= 55000 and Cases[q1] < 60000):
            earth.plot(x, y, 'ro',markersize=60,alpha=.35)
            
        elif (Cases[q1] >= 60000 and Cases[q1] < 65000):
            earth.plot(x, y, 'ro',markersize=65,alpha=.35)
            
        elif (Cases[q1] >= 65000 and Cases[q1] < 70000):
            earth.plot(x, y, 'ro',markersize=70,alpha=.35)
            
        elif (Cases[q1] >= 70000 and Cases[q1] < 75000):
            earth.plot(x, y, 'ro',markersize=75,alpha=.35)
            
        elif (Cases[q1] >= 75000 and Cases[q1] < 80000):
            earth.plot(x, y, 'ro',markersize=80,alpha=.35)
            
        elif (Cases[q1] >= 80000 and Cases[q1] < 85000):
            earth.plot(x, y, 'ro',markersize=85,alpha=.35)
            
        elif (Cases[q1] >= 85000 and Cases[q1] < 90000):
            earth.plot(x, y, 'ro',markersize=90,alpha=.35)
            
        elif (Cases[q1] >= 90000 and Cases[q1] < 95000):
            earth.plot(x, y, 'ro',markersize=95,alpha=.35)
            
        elif (Cases[q1] >= 95000 and Cases[q1] < 100000):
            earth.plot(x, y, 'ro',markersize=100,alpha=.35)
            
        elif (Cases[q1] >= 100000 and Cases[q1] < 105000):
            earth.plot(x, y, 'ro',markersize=105,alpha=.35)
            
        elif (Cases[q1] >= 105000 and Cases[q1] < 110000):
            earth.plot(x, y, 'ro',markersize=110,alpha=.35)
            
        elif (Cases[q1] >= 110000 and Cases[q1] < 115000):
            earth.plot(x, y, 'ro',markersize=115,alpha=.35)
            
        elif (Cases[q1] >= 115000 and Cases[q1] < 120000):
            earth.plot(x, y, 'ro',markersize=120,alpha=.35)
            
        elif (Cases[q1] >= 120000 and Cases[q1] < 125000):
            earth.plot(x, y, 'ro',markersize=125,alpha=.35)
            
        elif (Cases[q1] >= 125000 and Cases[q1] < 130000):
            earth.plot(x, y, 'ro',markersize=130,alpha=.35)
            
        elif (Cases[q1] >= 130000 and Cases[q1] < 135000):
            earth.plot(x, y, 'ro',markersize=135,alpha=.35)
            
        elif (Cases[q1] >= 135000 and Cases[q1] < 140000):
            earth.plot(x, y, 'ro',markersize=140,alpha=.35)
    q1 += 1
    
plt.title("Measles outbreaks (100557844)")
plt.show()




#Rubella
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

        
plt.figure(figsize=(12, 12))
earth = Basemap(projection='mill')
earth.fillcontinents(color='0.85')
earth.drawcoastlines(color='0.60', linewidth=0.55)        
        
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))


 #if Rubella is found increase size the more cases that are there
for i in range (q2, len(Category)):
    if (Category[q2] == 'Rubella'):
        x, y = earth(Long[q2], Lat[q2])
        
        if (Cases[q2] >= 0 and Cases[q2] < 5000):
            earth.plot(x, y, 'mo',markersize=5,alpha=.35)
            
        elif (Cases[q2] >= 5000 and Cases[q2] < 10000):
            earth.plot(x, y, 'mo',markersize=10,alpha=.35)
            
        elif (Cases[q2] >= 10000 and Cases[q2] < 15000):
            earth.plot(x, y, 'mo',markersize=15,alpha=.35)
            
        elif (Cases[q2] >= 15000 and Cases[q2] < 20000):
            earth.plot(x, y, 'mo',markersize=20,alpha=.35)
            
        elif (Cases[q2] >= 20000 and Cases[q2] < 25000):
            earth.plot(x, y, 'mo',markersize=25,alpha=.35)
            
        elif (Cases[q2] >= 25000 and Cases[q2] < 30000):
            earth.plot(x, y, 'mo',markersize=30,alpha=.35)
            
        elif (Cases[q2] >= 30000 and Cases[q2] < 35000):
            earth.plot(x, y, 'mo',markersize=35,alpha=.35)
            
        elif (Cases[q2] >= 35000 and Cases[q2] < 40000):
            earth.plot(x, y, 'mo',markersize=40,alpha=.35)
            
        elif (Cases[q2] >= 40000 and Cases[q2] < 45000):
            earth.plot(x, y, 'mo',markersize=45,alpha=.35)
            
        elif (Cases[q2] >= 45000 and Cases[q2] < 50000):
            earth.plot(x, y, 'mo',markersize=50,alpha=.35)
            
        elif (Cases[q2] >= 50000 and Cases[q2] < 55000):
            earth.plot(x, y, 'mo',markersize=55,alpha=.35)
            
        elif (Cases[q2] >= 55000 and Cases[q2] < 60000):
            earth.plot(x, y, 'mo',markersize=60,alpha=.35)
            
        elif (Cases[q2] >= 60000 and Cases[q2] < 65000):
            earth.plot(x, y, 'mo',markersize=65,alpha=.35)
            
        elif (Cases[q2] >= 65000 and Cases[q2] < 70000):
            earth.plot(x, y, 'mo',markersize=70,alpha=.35)
            
        elif (Cases[q2] >= 70000 and Cases[q2] < 75000):
            earth.plot(x, y, 'mo',markersize=75,alpha=.35)
            
        elif (Cases[q2] >= 75000 and Cases[q2] < 80000):
            earth.plot(x, y, 'mo',markersize=80,alpha=.35)
            
        elif (Cases[q2] >= 80000 and Cases[q2] < 85000):
            earth.plot(x, y, 'mo',markersize=85,alpha=.35)
            
        elif (Cases[q2] >= 85000 and Cases[q2] < 90000):
            earth.plot(x, y, 'mo',markersize=90,alpha=.35)
            
        elif (Cases[q2] >= 90000 and Cases[q2] < 95000):
            earth.plot(x, y, 'mo',markersize=95,alpha=.35)
            
        elif (Cases[q2] >= 95000 and Cases[q2] < 100000):
            earth.plot(x, y, 'mo',markersize=100,alpha=.35)
            
        elif (Cases[q2] >= 100000 and Cases[q2] < 105000):
            earth.plot(x, y, 'mo',markersize=105,alpha=.35)
            
        elif (Cases[q2] >= 105000 and Cases[q2] < 110000):
            earth.plot(x, y, 'mo',markersize=110,alpha=.35)
            
        elif (Cases[q2] >= 110000 and Cases[q2] < 115000):
            earth.plot(x, y, 'mo',markersize=115,alpha=.35)
            
        elif (Cases[q2] >= 115000 and Cases[q2] < 120000):
            earth.plot(x, y, 'mo',markersize=120,alpha=.35)
            
        elif (Cases[q2] >= 120000 and Cases[q2] < 125000):
            earth.plot(x, y, 'mo',markersize=125,alpha=.35)
            
        elif (Cases[q2] >= 125000 and Cases[q2] < 130000):
            earth.plot(x, y, 'mo',markersize=130,alpha=.35)
            
        elif (Cases[q2] >= 130000 and Cases[q2] < 135000):
            earth.plot(x, y, 'mo',markersize=135,alpha=.35)
    
        elif (Cases[q2] >= 135000 and Cases[q2] < 140000):
            earth.plot(x, y, 'mo',markersize=140,alpha=.35)

    q2 += 1      
    
plt.title("Rubella outbreaks (100557844)")
plt.show()




#Mumps
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

plt.figure(figsize=(12, 12))
earth = Basemap(projection='mill')
earth.fillcontinents(color='0.85')
earth.drawcoastlines(color='0.60', linewidth=0.55)
        
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

 #if Mumps is found increase size the more cases that are there
for q3 in range (q3, len(Category)):
    if (Category[q3] == 'Mumps'):
        x, y = earth(Long[q3], Lat[q3])
        
        if (Cases[q3] >= 0 and Cases[q3] < 5000):
            earth.plot(x, y, 'go',markersize=5,alpha=.35)
            
        elif (Cases[q3] >= 5000 and Cases[q3] < 10000):
            earth.plot(x, y, 'go',markersize=10,alpha=.35)
            
        elif (Cases[q3] >= 10000 and Cases[q3] < 15000):
            earth.plot(x, y, 'go',markersize=15,alpha=.35)
            
        elif (Cases[q3] >= 15000 and Cases[q3] < 20000):
            earth.plot(x, y, 'go',markersize=20,alpha=.35)
            
        elif (Cases[q3] >= 20000 and Cases[q3] < 25000):
            earth.plot(x, y, 'go',markersize=25,alpha=.35)
            
        elif (Cases[q3] >= 25000 and Cases[q3] < 30000):
            earth.plot(x, y, 'go',markersize=30,alpha=.35)
            
        elif (Cases[q3] >= 30000 and Cases[q3] < 35000):
            earth.plot(x, y, 'go',markersize=35,alpha=.35)
            
        elif (Cases[q3] >= 35000 and Cases[q3] < 40000):
            earth.plot(x, y, 'go',markersize=40,alpha=.35)
            
        elif (Cases[q3] >= 40000 and Cases[q3] < 45000):
            earth.plot(x, y, 'go',markersize=45,alpha=.35)
            
        elif (Cases[q3] >= 45000 and Cases[q3] < 50000):
            earth.plot(x, y, 'go',markersize=50,alpha=.35)
            
        elif (Cases[q3] >= 50000 and Cases[q3] < 55000):
            earth.plot(x, y, 'go',markersize=55,alpha=.35)
            
        elif (Cases[q3] >= 55000 and Cases[q3] < 60000):
            earth.plot(x, y, 'go',markersize=60,alpha=.35)
            
        elif (Cases[q3] >= 60000 and Cases[q3] < 65000):
            earth.plot(x, y, 'go',markersize=65,alpha=.35)
            
        elif (Cases[q3] >= 65000 and Cases[q3] < 70000):
            earth.plot(x, y, 'go',markersize=70,alpha=.35)
            
        elif (Cases[q3] >= 70000 and Cases[q3] < 75000):
            earth.plot(x, y, 'go',markersize=75,alpha=.35)
            
        elif (Cases[q3] >= 75000 and Cases[q3] < 80000):
            earth.plot(x, y, 'go',markersize=80,alpha=.35)
            
        elif (Cases[q3] >= 80000 and Cases[q3] < 85000):
            earth.plot(x, y, 'go',markersize=85,alpha=.35)
            
        elif (Cases[q3] >= 85000 and Cases[q3] < 90000):
            earth.plot(x, y, 'go',markersize=90,alpha=.35)
            
        elif (Cases[q3] >= 90000 and Cases[q3] < 95000):
            earth.plot(x, y, 'go',markersize=95,alpha=.35)
            
        elif (Cases[q3] >= 95000 and Cases[q3] < 100000):
            earth.plot(x, y, 'go',markersize=100,alpha=.35)
            
        elif (Cases[q3] >= 100000 and Cases[q3] < 105000):
            earth.plot(x, y, 'go',markersize=105,alpha=.35)
            
        elif (Cases[q3] >= 105000 and Cases[q3] < 110000):
            earth.plot(x, y, 'go',markersize=110,alpha=.35)
            
        elif (Cases[q3] >= 110000 and Cases[q3] < 115000):
            earth.plot(x, y, 'go',markersize=115,alpha=.35)
            
        elif (Cases[q3] >= 115000 and Cases[q3] < 120000):
            earth.plot(x, y, 'go',markersize=120,alpha=.35)
            
        elif (Cases[q3] >= 120000 and Cases[q3] < 125000):
            earth.plot(x, y, 'go',markersize=125,alpha=.35)
            
        elif (Cases[q3] >= 125000 and Cases[q3] < 130000):
            earth.plot(x, y, 'go',markersize=130,alpha=.35)
            
        elif (Cases[q3] >= 130000 and Cases[q3] < 135000):
            earth.plot(x, y, 'go',markersize=135,alpha=.35)
    
        elif (Cases[q3] >= 135000 and Cases[q3] < 140000):
            earth.plot(x, y, 'go',markersize=140,alpha=.35)

    q3 += 1      
    
plt.title("Mumps outbreaks (100557844)")
plt.show()






#Polio
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))

plt.figure(figsize=(12, 12))
earth = Basemap(projection='mill')
earth.fillcontinents(color='0.85')
earth.drawcoastlines(color='0.60', linewidth=0.55)
        
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))

q4 = 0
 #if Polio is found increase size the more cases that are there
for i in range (q4, len(Category)):
    if (Category[q4] == 'Polio'):
        x, y = earth(Long[q4], Lat[q4])
        
        if (Cases[q4] >= 0 and Cases[q4] < 5000):
            earth.plot(x, y, 'bo',markersize=5,alpha=.35)
            
        elif (Cases[q4] >= 5000 and Cases[q4] < 10000):
            earth.plot(x, y, 'bo',markersize=10,alpha=.35)
            
        elif (Cases[q4] >= 10000 and Cases[q4] < 15000):
            earth.plot(x, y, 'bo',markersize=15,alpha=.35)
            
        elif (Cases[q4] >= 15000 and Cases[q4] < 20000):
            earth.plot(x, y, 'bo',markersize=20,alpha=.35)
            
        elif (Cases[q4] >= 20000 and Cases[q4] < 25000):
            earth.plot(x, y, 'bo',markersize=25,alpha=.35)
            
        elif (Cases[q4] >= 25000 and Cases[q4] < 30000):
            earth.plot(x, y, 'bo',markersize=30,alpha=.35)
            
        elif (Cases[q4] >= 30000 and Cases[q4] < 35000):
            earth.plot(x, y, 'bo',markersize=35,alpha=.35)
            
        elif (Cases[q4] >= 35000 and Cases[q4] < 40000):
            earth.plot(x, y, 'bo',markersize=40,alpha=.35)
            
        elif (Cases[q4] >= 40000 and Cases[q4] < 45000):
            earth.plot(x, y, 'bo',markersize=45,alpha=.35)
            
        elif (Cases[q4] >= 45000 and Cases[q4] < 50000):
            earth.plot(x, y, 'bo',markersize=50,alpha=.35)
            
        elif (Cases[q4] >= 50000 and Cases[q4] < 55000):
            earth.plot(x, y, 'bo',markersize=55,alpha=.35)
            
        elif (Cases[q4] >= 55000 and Cases[q4] < 60000):
            earth.plot(x, y, 'bo',markersize=60,alpha=.35)
            
        elif (Cases[q4] >= 60000 and Cases[q4] < 65000):
            earth.plot(x, y, 'bo',markersize=65,alpha=.35)
            
        elif (Cases[q4] >= 65000 and Cases[q4] < 70000):
            earth.plot(x, y, 'bo',markersize=70,alpha=.35)
            
        elif (Cases[q4] >= 70000 and Cases[q4] < 75000):
            earth.plot(x, y, 'bo',markersize=75,alpha=.35)
            
        elif (Cases[q4] >= 75000 and Cases[q4] < 80000):
            earth.plot(x, y, 'bo',markersize=80,alpha=.35)
            
        elif (Cases[q4] >= 80000 and Cases[q4] < 85000):
            earth.plot(x, y, 'bo',markersize=85,alpha=.35)
            
        elif (Cases[q4] >= 85000 and Cases[q4] < 90000):
            earth.plot(x, y, 'bo',markersize=90,alpha=.35)
            
        elif (Cases[q4] >= 90000 and Cases[q4] < 95000):
            earth.plot(x, y, 'bo',markersize=95,alpha=.35)
            
        elif (Cases[q4] >= 95000 and Cases[q4] < 100000):
            earth.plot(x, y, 'bo',markersize=100,alpha=.35)
            
        elif (Cases[q4] >= 100000 and Cases[q4] < 105000):
            earth.plot(x, y, 'bo',markersize=105,alpha=.35)
            
        elif (Cases[q4] >= 105000 and Cases[q4] < 110000):
            earth.plot(x, y, 'bo',markersize=110,alpha=.35)
            
        elif (Cases[q4] >= 110000 and Cases[q4] < 115000):
            earth.plot(x, y, 'bo',markersize=115,alpha=.35)
            
        elif (Cases[q4] >= 115000 and Cases[q4] < 120000):
            earth.plot(x, y, 'bo',markersize=120,alpha=.35)
            
        elif (Cases[q4] >= 120000 and Cases[q4] < 125000):
            earth.plot(x, y, 'bo',markersize=125,alpha=.35)
            
        elif (Cases[q4] >= 125000 and Cases[q4] < 130000):
            earth.plot(x, y, 'bo',markersize=130,alpha=.35)
            
        elif (Cases[q4] >= 130000 and Cases[q4] < 135000):
            earth.plot(x, y, 'bo',markersize=135,alpha=.35)
    
        elif (Cases[q4] >= 135000 and Cases[q4] < 140000):
            earth.plot(x, y, 'bo',markersize=140,alpha=.35)

    q4 += 1      
    
plt.title("Polio outbreaks (100557844)")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
